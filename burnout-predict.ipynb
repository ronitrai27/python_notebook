# %%
# LOAD THE DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('data/ai-dev-data.csv')
df.head()
# Out:
#     User_ID  Day Experience_Level  AI_Tool_Usage_%  Hours_Coded  \
# 0  DEV_0001    1           Junior             26.7          7.4
# 1  DEV_0001    2           Junior              0.0         11.6
# 2  DEV_0001    3           Junior             18.7          7.7
# 3  DEV_0001    4           Junior             13.0          7.7
# 4  DEV_0001    5           Junior             22.8          7.6
#
#    Code_Complexity_Score  Bugs_Introduced  Tasks_Completed  Stress_Level_1_10  \
# 0                      5                2             6.98                  5
# 1                      3                2             8.35                  6
# 2                      9                3             7.11                  6
# 3                      7                3             7.10                  6
# 4                      6                3             7.05                  6
#
#    Current_Burnout_Score Burnout_Risk
# 0                   97.0         High
# ...
